# %%
from ultralytics import YOLO

cls_model = YOLO("yolo11n-cls.pt")   # ImageNet pretrained classifier

cls_model.train(
    data= "D:\IITBHU Internship\datasets\drone_classify",  # root with train/val inside
    epochs=15,
    imgsz=224,
    batch=16,
    device=0,
    workers=0,     
    cache=False
)
# Out:
# Ultralytics 8.3.235  Python-3.11.13 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...
